# %%
import numpy as np
ref = np.loadtxt('resRef.txt',dtype="float64")
y = ref[:,2]
l = int(np.sqrt(len(y)))
y_grid = y.reshape((l,l))
import pylab as plt
plt.imshow(y_grid, cmap="hot")
plt.axis(False) 
plt.colorbar()

# %%
dt = 0.0005
temp_t = 2.5
Nitmax = temp_t/dt
Nitmax
# Out:
# 5000.0
